# %%
import pandas as pd

batting_df = pd.read_csv("batting_feature_engineered.csv")
bowling_df = pd.read_csv("bowling_feature_engineered.csv")

batting_df['date'] = pd.to_datetime(batting_df['date'])
bowling_df['date'] = pd.to_datetime(bowling_df['date'])

# %%
batting_df.head()
# Out:
#    matchId         batsman  runs_in_match season  \
# 0   548346  A Ashish Reddy           10.0   2012
# 1   548352  A Ashish Reddy            3.0   2012
# 2   548359  A Ashish Reddy            8.0   2012
# 3   548373  A Ashish Reddy           10.0   2012
# 4   548376  A Ashish Reddy            4.0   2012
#
#                                        venue                team1  \
# 0                           Wankhede Stadium       Mumbai Indians
# 1            MA Chidambaram Stadium, Chepauk  Chennai Super Kings
# 2  Rajiv Gandhi International Stadium, Uppal      Deccan Chargers
# 3  Rajiv Gandhi International Stadium, Uppal      Deccan Chargers
# 4  Rajiv Gandhi International Stadium, Uppal      Deccan Chargers
#
#                          team2       date     batting_team  \
# 0              Deccan Chargers 2012-04-29  Deccan Chargers
# 1              Deccan Chargers 2012-05-04  Deccan Chargers
# 2              Kings XI Punjab 2012-05-08  Deccan Chargers
# 3             Rajasthan Royals 2012-05-18  Deccan Chargers
# 4  Royal Challengers Bangalore 2012-05-20  Deccan Chargers
#
#                  opponent_team  avg_last_3  avg_last_5  avg_last_10  \
# 0               Mumbai Indians   10.000000       10.00        10.00
# 1          Chennai Super Kings    6.500000        6.50         6.50
# 2              Kings XI Punjab    7.000000        7.00         7.00
# 3             Rajasthan Royals    7.000000        7.75         7.75
# 4  Royal Challengers Bangalore    7.333333        7.00         7.00
#
#    avg_at_venue  avg_vs_opponent  career_avg
# 0     10.000000        13.500000   12.173913
# 1     19.500000        15.000000   12.173913
# 2      8.454545        12.333333   12.173913
# 3      8.454545        12.333333   12.173913
# 4      8.454545        11.000000   12.173913

# %%
batting_df = batting_df.sort_values(['batsman', 'date'])
bowling_df = bowling_df.sort_values(['bowler', 'date'])

# %%
batting_df['avg_last_5'] = (
    batting_df.groupby('batsman')['runs_in_match']
    .shift(1)
    .rolling(5)
    .mean()
)

batting_df['avg_last_10'] = (
    batting_df.groupby('batsman')['runs_in_match']
    .shift(1)
    .rolling(10)
    .mean()
)

# %%
bowling_df['avg_last_5'] = (
    bowling_df.groupby('bowler')['wickets_in_match']
    .shift(1)
    .rolling(5)
    .mean()
)

# %%
batting_df['venue_avg'] = (
    batting_df.groupby(['batsman', 'venue'])['runs_in_match']
    .transform('mean')
)

batting_df['opponent_avg'] = (
    batting_df.groupby(['batsman', 'opponent_team'])['runs_in_match']
    .transform('mean')
)

# %%
batting_df['career_avg'] = (
    batting_df.groupby('batsman')['runs_in_match']
    .expanding()
    .mean()
    .shift(1)
    .reset_index(level=0, drop=True)
)

# %%
target = 'runs_in_match'

# %%
batting_df = batting_df.fillna(0)

# %%
batting_df.to_csv("dataset.csv", index=False)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
import joblib

# %%
categorical_cols = ['batting_team', 'opponent_team', 'venue', 'season']
numeric_cols = [c for c in batting_df.columns
                if c not in categorical_cols + ['batsman','date','matchId','runs_in_match']]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols),
        ('num', 'passthrough', numeric_cols)
    ]
)

# %%
joblib.dump(preprocessor, "feature_pipeline.pkl")
# Out:
# ['feature_pipeline.pkl']

# %%
batting_df = batting_df.sort_values(['batsman', 'date'])

batting_df['avg_last_5'] = (
    batting_df.groupby('batsman')['runs_in_match']
    .shift(1)
    .rolling(5)
    .mean()
)

batting_df['avg_last_10'] = (
    batting_df.groupby('batsman')['runs_in_match']
    .shift(1)
    .rolling(10)
    .mean()
)

# %%
batting_df['target_runs'] = (
    batting_df.groupby('batsman')['runs_in_match'].shift(-1)
)
